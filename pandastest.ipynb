# %%
import pandas as pd
df = pd.read_csv('scraped_data.csv')
print(df)
# Out:
#                                                 title      category  \
# 0   ศาลฎีกาฯ นัดอ่านคำพิพากษาคดี ‘ยิ่งลักษณ์’ ใช้อ...  ['Politics']
# 1   นายกฯ ห่วงปมนักศึกษากู้ กยศ. ไม่ผ่าน กระทรวงกา...  ['Politics']
# 2   รัดเกล้าชูมาตรการแก้ปัญหาหนี้ทั้งใน-นอกระบบ ด้...  ['Politics']
# 3   ‘ไทยก้าวหน้า’ ประกาศขออยู่ตรงกลาง เน้นทำงานตรว...  ['Politics']
# 4   เกรียงกำชับผู้ว่าฯ อุดรธานี กวาดล้างหนี้เทียม-...  ['Politics']
# ..                                                ...           ...
# 65  ย้ำดิจิทัลวอลเล็ต ไม่ใช่แจกเงินทั่วไป ส่วนร่าง...  ['Politics']
# 66  จับตาอนาคตทางการเมือง ‘ประวิตร’ หลังขนแกนนำ – ...  ['Politics']
# 67  นายกฯ เตรียมแถลงแก้หนี้นอกระบบ 28 พ.ย. รองโฆษก...  ['Politics']
# 68  เศรษฐามองสระแก้วเป็นจังหวัดศักยภาพสูง พร้อมพิจ...  ['Politics']
# 69  นายกฯ ลงพื้นที่สระแก้ว ตรวจราชการด่านชายแดนอรั...  ['Politics']
#
#                author        date  entry-view  \
# 0   THE STANDARD TEAM  03.12.2023          82
# 1   THE STANDARD TEAM  03.12.2023          46
# ...

# %%
df
# Out:
#                                                 title      category  \
# 0   ศาลฎีกาฯ นัดอ่านคำพิพากษาคดี ‘ยิ่งลักษณ์’ ใช้อ...  ['Politics']
# 1   นายกฯ ห่วงปมนักศึกษากู้ กยศ. ไม่ผ่าน กระทรวงกา...  ['Politics']
# 2   รัดเกล้าชูมาตรการแก้ปัญหาหนี้ทั้งใน-นอกระบบ ด้...  ['Politics']
# 3   ‘ไทยก้าวหน้า’ ประกาศขออยู่ตรงกลาง เน้นทำงานตรว...  ['Politics']
# 4   เกรียงกำชับผู้ว่าฯ อุดรธานี กวาดล้างหนี้เทียม-...  ['Politics']
# ..                                                ...           ...
# 65  ย้ำดิจิทัลวอลเล็ต ไม่ใช่แจกเงินทั่วไป ส่วนร่าง...  ['Politics']
# 66  จับตาอนาคตทางการเมือง ‘ประวิตร’ หลังขนแกนนำ – ...  ['Politics']
# 67  นายกฯ เตรียมแถลงแก้หนี้นอกระบบ 28 พ.ย. รองโฆษก...  ['Politics']
# 68  เศรษฐามองสระแก้วเป็นจังหวัดศักยภาพสูง พร้อมพิจ...  ['Politics']
# 69  นายกฯ ลงพื้นที่สระแก้ว ตรวจราชการด่านชายแดนอรั...  ['Politics']
#
#                author        date  entry-view  \
# 0   THE STANDARD TEAM  03.12.2023          82
# 1   THE STANDARD TEAM  03.12.2023          46
# ...
